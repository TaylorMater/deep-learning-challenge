# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
application_df.head(25)
# Out:
#          EIN                                               NAME  \
# 0   10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1   10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2   10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3   10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4   10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# 5   10556855  MINORITY ORGAN & TISSUE TRANSPLANT & EDUCATION...
# 6   10558440  FRIENDS OF ARTS COUNCIL OF GREATER DENHAM SPRI...
# 7   10566033                          ISRAEL EMERGENCY ALLIANCE
# 8   10570430                                   ARAMCO BRATS INC
# 9   10571689         INTERNATIONAL ASSOCIATION OF FIRE FIGHTERS
# 10  10573059                      KAI ELUA OUTRIGGER CANOE CLUB
# 11  10575727                                   HERITAGE ACADEMY
# 12  10583569                   THE UNITED STATES PONY CLUBS INC
# 13  10585206  DOMINION INTERNATIONAL NETWORK OF MINISTRIES &...
# 14  10585443                                   V O W FOUNDATION
# 15  10596727                     JOSEPH E PEEBLES JR FOUNDATION
# 16  10602428  WASHINGTON ASSOCIATION OF PHYSICIANS OF INDIAN...
# 17  10603214                   SAINT FRANCIS HOSPITAL SOUTH LLC
# 18  10604986         ANCHORAGE COMMUNITY MENTAL HEALTH SERVICES
# 19  10605038             HABITAT FOR HUMANITY INTERNATIONAL INC
# 20  10608689                      INTERNATIONAL FELINE SHOWCASE
# 21  10612407                   METAMORPHASIS POWERHOUSE COMPANY
# 22  10614724                           REACH FOR EXCELLENCE INC
# 23  10622557            INTERNATIONAL ASSOCIATION OF LIONS CLUB
# 24  10623527                   SONS OF CONFEDERATE VETERANS INC
#
#    APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0               T10       Independent          C1000    ProductDev
# 1                T3       Independent          C2000  Preservation
# 2                T5  CompanySponsored          C3000    ProductDev
# 3                T3  CompanySponsored          C2000  Preservation
# 4                T3       Independent          C1000     Heathcare
# 5                T3       Independent          C1200  Preservation
# 6                T3       Independent          C1000  Preservation
# 7                T3       Independent          C2000  Preservation
# 8                T7       Independent          C1000    ProductDev
# 9                T5  CompanySponsored          C3000    ProductDev
# 10               T3       Independent          C1200  Preservation
# 11               T3       Independent          C2000  Preservation
# 12               T3  CompanySponsored          C1200  Preservation
# 13               T3       Independent          C2700  Preservation
# 14               T3       Independent          C1000  Preservation
# 15               T3       Independent          C1200  Preservation
# 16               T3       Independent          C2000  Preservation
# 17               T3       Independent          C1000     Heathcare
# 18               T3  CompanySponsored          C1000  Preservation
# 19               T3  CompanySponsored          C1000  Preservation
# 20               T4       Independent          C3000    ProductDev
# 21               T3       Independent          C1200  Preservation
# 22               T3       Independent          C7000  Preservation
# 23               T4  CompanySponsored          C3000    ProductDev
# 24               T3  CompanySponsored          C1200  Preservation
#
#     ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0    Association       1              0                      N      5000
# 1   Co-operative       1         1-9999                      N    108590
# 2    Association       1              0                      N      5000
# 3          Trust       1    10000-24999                      N      6692
# 4          Trust       1  100000-499999                      N    142590
# 5          Trust       1              0                      N      5000
# 6          Trust       1  100000-499999                      N     31452
# 7          Trust       1        10M-50M                      N   7508025
# 8          Trust       1         1-9999                      N     94389
# 9    Association       1              0                      N      5000
# 10         Trust       1    25000-99999                      N     69656
# 11         Trust       1  100000-499999                      N    165593
# 12   Association       1              0                      N      5000
# 13         Trust       1    25000-99999                      N      5301
# 14         Trust       1              0                      N      5000
# 15         Trust       1              0                      N      5000
# 16         Trust       1              0                      N      5000
# 17         Trust       1           50M+                      N  86380556
# 18         Trust       1              0                      N      5000
# 19         Trust       1  100000-499999                      N    376109
# 20         Trust       1              0                      N      5000
# 21         Trust       1              0                      N      5000
# 22         Trust       1  100000-499999                      N    318296
# 23   Association       1              0                      N      5000
# 24         Trust       1              0                      N      5000
#
#     IS_SUCCESSFUL
# 0               1
# 1               1
# 2               0
# 3               1
# 4               1
# 5               1
# 6               1
# 7               1
# 8               1
# 9               0
# 10              0
# 11              0
# 12              1
# 13              1
# 14              1
# 15              1
# 16              1
# 17              0
# 18              0
# 19              0
# 20              1
# 21              1
# 22              0
# 23              0
# 24              0

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.

application_df.drop(['EIN', 'NAME'], axis=1, inplace=True)

# %%
# Determine the number of unique values in each column.


application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
for col in application_df:
  print(application_df[col].unique())
# Out:
# ['T10' 'T3' 'T5' 'T7' 'T4' 'T6' 'T2' 'T9' 'T19' 'T8' 'T13' 'T12' 'T29'
#  'T25' 'T14' 'T17' 'T15']
# ['Independent' 'CompanySponsored' 'Family/Parent' 'National' 'Regional'
#  'Other']
# ['C1000' 'C2000' 'C3000' 'C1200' 'C2700' 'C7000' 'C7200' 'C1700' 'C4000'
#  'C7100' 'C2800' 'C6000' 'C2100' 'C1238' 'C5000' 'C7120' 'C1800' 'C4100'
#  'C1400' 'C1270' 'C2300' 'C8200' 'C1500' 'C7210' 'C1300' 'C1230' 'C1280'
#  'C1240' 'C2710' 'C2561' 'C1250' 'C8000' 'C1245' 'C1260' 'C1235' 'C1720'
#  'C1257' 'C4500' 'C2400' 'C8210' 'C1600' 'C1278' 'C1237' 'C4120' 'C2170'
#  'C1728' 'C1732' 'C2380' 'C1283' 'C1570' 'C2500' 'C1267' 'C3700' 'C1580'
#  'C2570' 'C1256' 'C1236' 'C1234' 'C1246' 'C2190' 'C4200' 'C0' 'C3200'
#  'C5200' 'C1370' 'C2600' 'C1248' 'C6100' 'C1820' 'C1900' 'C2150']
# ['ProductDev' 'Preservation' 'Heathcare' 'CommunityServ' 'Other']
# ['Association' 'Co-operative' 'Trust' 'Corporation']
# [1 0]
# ['0' '1-9999' '10000-24999' '100000-499999' '10M-50M' '25000-99999' '50M+'
#  '1M-5M' '5M-10M']
# ['N' 'Y']
# [    5000   108590     6692 ...     6713    20197 36500179]
# [1 0]

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

#using cutoff of 500 counts, as in example output
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].unique()
# Out:
# array(['C1000', 'C2000', 'C3000', 'C1200', 'C2700', 'C7000', 'C7200',
#        'C1700', 'C4000', 'C7100', 'C2800', 'C6000', 'C2100', 'C1238',
#        'C5000', 'C7120', 'C1800', 'C4100', 'C1400', 'C1270', 'C2300',
#        'C8200', 'C1500', 'C7210', 'C1300', 'C1230', 'C1280', 'C1240',
#        'C2710', 'C2561', 'C1250', 'C8000', 'C1245', 'C1260', 'C1235',
#        'C1720', 'C1257', 'C4500', 'C2400', 'C8210', 'C1600', 'C1278',
#        'C1237', 'C4120', 'C2170', 'C1728', 'C1732', 'C2380', 'C1283',
#        'C1570', 'C2500', 'C1267', 'C3700', 'C1580', 'C2570', 'C1256',
#        'C1236', 'C1234', 'C1246', 'C2190', 'C4200', 'C0', 'C3200',
#        'C5200', 'C1370', 'C2600', 'C1248', 'C6100', 'C1820', 'C1900',
#        'C2150'], dtype=object)

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

#replacing everything but the top 5
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883

classifications_to_replace = [ 'C2700', 'C7000', 'C7200','C1700', 'C4000', 'C7100', 'C2800', 'C6000', 'C1238',
       'C5000', 'C7120', 'C1800', 'C4100', 'C1400', 'C1270', 'C2300',
       'C8200', 'C1500', 'C7210', 'C1300', 'C1230', 'C1280', 'C1240',
       'C2710', 'C2561', 'C1250', 'C8000', 'C1245', 'C1260', 'C1235',
       'C1720', 'C1257', 'C4500', 'C2400', 'C8210', 'C1600', 'C1278',
       'C1237', 'C4120', 'C2170', 'C1728', 'C1732', 'C2380', 'C1283',
       'C1570', 'C2500', 'C1267', 'C3700', 'C1580', 'C2570', 'C1256',
       'C1236', 'C1234', 'C1246', 'C2190', 'C4200', 'C0', 'C3200',
       'C5200', 'C1370', 'C2600', 'C1248', 'C6100', 'C1820', 'C1900', 'C2150']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(application_df)

# %%
dummies_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                   False
# 1           1    108590              1                   False
# 2           1      5000              0                   False
# 3           1      6692              1                   False
# 4           1    142590              1                   False
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                   False
# 34295       1      5000              0                   False
# 34296       1      5000              0                   False
# 34297       1      5000              1                   False
# 34298       1  36500179              0                   False
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                      True                 False                False
# 1                     False                 False                 True
# 2                     False                 False                False
# 3                     False                 False                 True
# 4                     False                 False                 True
# ...                     ...                   ...                  ...
# 34294                 False                 False                False
# 34295                 False                 False                False
# 34296                 False                 False                 True
# 34297                 False                 False                False
# 34298                 False                 False                 True
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    False                False                False  ...
# 1                    False                False                False  ...
# 2                    False                 True                False  ...
# 3                    False                False                False  ...
# 4                    False                False                False  ...
# ...                    ...                  ...                  ...  ...
# 34294                 True                False                False  ...
# 34295                 True                False                False  ...
# 34296                False                False                False  ...
# 34297                False                 True                False  ...
# 34298                False                False                False  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                  False                   False                     False
# 1                   True                   False                     False
# 2                  False                   False                     False
# 3                  False                    True                     False
# 4                  False                   False                      True
# ...                  ...                     ...                       ...
# 34294              False                   False                     False
# 34295              False                   False                     False
# 34296              False                   False                     False
# 34297              False                   False                     False
# 34298              False                   False                     False
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                   False             False                   False
# 1                   False             False                   False
# 2                   False             False                   False
# 3                   False             False                   False
# 4                   False             False                   False
# ...                   ...               ...                     ...
# 34294               False             False                   False
# 34295               False             False                   False
# 34296               False             False                   False
# 34297               False             False                   False
# 34298               False              True                   False
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                False              False                      True
# 1                False              False                      True
# 2                False              False                      True
# 3                False              False                      True
# 4                False              False                      True
# ...                ...                ...                       ...
# 34294            False              False                      True
# 34295            False              False                      True
# 34296            False              False                      True
# 34297            False              False                      True
# 34298            False              False                      True
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 34294                     False
# 34295                     False
# 34296                     False
# 34297                     False
# 34298                     False
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays

target = application_df['IS_SUCCESSFUL']

features = dummies_df.copy()
features.drop('IS_SUCCESSFUL', inplace=True, axis=1)


# Split the preprocessed data into a training and testing dataset
X = features
y = target

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
input_dim = X_train_scaled.shape[1]

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=1, activation='relu', input_dim=input_dim))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation='relu'))




# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 44
#
#  dense_1 (Dense)             (None, 20)                40
#
#  dense_2 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 105 (420.00 Byte)
# Trainable params: 105 (420.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6762 - accuracy: 0.6471
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6464 - accuracy: 0.6586
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6309 - accuracy: 0.6641
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6236 - accuracy: 0.6661
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6198 - accuracy: 0.6629
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6174 - accuracy: 0.6646
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6158 - accuracy: 0.6633
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6147 - accuracy: 0.6643
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6142 - accuracy: 0.6626
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6134 - accuracy: 0.6623
# Epoch 11/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6128 - accuracy: 0.6645
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6123 - accuracy: 0.6649
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6117 - accuracy: 0.6637
# Epoch 14/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6116 - accuracy: 0.6626
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6112 - accuracy: 0.6640
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6113 - accuracy: 0.6649
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.